# %%
# Day-2 Variable and data types
x=10
x
'''
interger /float
string
Booleans
'''
# Out:
# 10

# %%
x=10  #integer
x
y=3.14
y
name="omics"
name
z=True
z
# Out:
# True

# %%
# variable rule
height_cm=120
#naming
total_sale=1000 # snake case
#camel case
totalSale=1000

totalSale == total_sale
# Out:
# True

# %%
# price$usd=10  not valid

# %%
x=10
X=10
x==X
# Out:
# True

# %%
# # numeric -interger(whole number),float(decial),complex(imaginary)
x=10+2j
type(x)
# Out:
# complex

# %%
# String -text,""
type(name)
# Out:
# str

# %%
# boolean-T/F
x=True
type(x)
# Out:
# bool

# %%
# isinstance
x=10
isinstance(x,bool)
# Out:
# False

# %%
#Using _class_
x="10.5"
x.__class__
# Out:
# str

# %%
age=20
age
age=age+10
print(age)
name=name+"Labs"
name
# Out:
# 30
# 'omicsLabsLabs'

# %%
a=100
b=200
c=a+b
c
# Out:
# 300

# %%
# Type casting
a='100'
a=int(a)
b=200
c=a+b
c
# Out:
# 300

# %%
num1=input("First number:")
num2=input("Second number:")
a=int(num1)
b=int(num2)
print(a+b)
# Out:
# First number:10
# Second number:20
# 30

# %%
num_string="123"
float_num=3.14
bool_val=False
print("Original declared DT")
print("Numerical string value:",num_string)
print("Numerical string:",type(num_string))

# type_casting
numeric_int=int(num_string)
print("Numerical int:",type(numeric_int))
# Out:
# Original declared DT
# Numerical string value: 123
# Numerical string: <class 'str'>
# Numerical int: <class 'int'>

# %%
# Arithmatic +,_,*,/,//,**,%
# Logical AND,OR Not (&,|,!=)
# Comaritive >,<,>=,<=,!=,==

# %%
print(10 <=10)
print(10 <=10 and 2<3)
print(10 <=10 or 2>3)
# Out:
# True
# True
# True

# %%
a=4
b=3
result=a*b
print(result)
# Out:
# 12

# %%
a=10
b=3
a//b
# Out:
# 3

# %%
a**b
10**10
# Out:
# 10000000000

# %%
a=12
b=3
z=a%b
z
# Out:
# 0
