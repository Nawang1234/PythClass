# %%
#I want to analyze the Hotel Magh 2079 data, available as a CSV file.

import pandas as pd
hotel_in_csv = pd.read_csv("Hotel Magh 2079.csv")
hotel_in_csv
# Out:
#       Unnamed: 0      Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0            NaN             NaN         NaN        NaN
# 1           DATE  INCOME/EXPENSE  DEPARTMENT       TYPE
# 2     01/10/2079          Income        Room        202
# 3     01/10/2079          Income        Room        204
# 4     01/10/2079          Income   Resturant        Bar
# ...          ...             ...         ...        ...
# 1480         NaN             NaN         NaN        NaN
# 1481         NaN             NaN         NaN        NaN
# 1482         NaN             NaN         NaN        NaN
# 1483         NaN             NaN         NaN        NaN
# 1484         NaN             NaN         NaN        NaN
#
#                                              Unnamed: 4     Unnamed: 5  \
# 0                                   MASTERSHEET OF MAGH            NaN
# 1                                       VENDOR/COSTUMER     PARTICULAR
# 2                                        Sujan Tulachan           Room
# ...

# %%
import pandas as pd

hotel_data.to_excel("Hotel Magh 2079.xlsx", sheet_name="magh", index=False)

# %%
#I want to see the first 8 rows of a pandas DataFrame.

hotel_data.head(8)
# Out:
# 1       DATE INCOME/EXPENSE DEPARTMENT  TYPE VENDOR/COSTUMER  \
# 0 2079-01-10         Income       Room   202  Sujan Tulachan
# 1 2079-01-10         Income       Room   204  Sujan Tulachan
# 2 2079-01-10         Income  Resturant   Bar  Sujan Tulachan
# 3 2079-01-10         Income  Resturant  Food  Sujan Tulachan
# 4 2079-01-10         Income  Resturant  Food  Sujan Tulachan
# 5 2079-01-10         Income  Resturant  Food  Sujan Tulachan
# 6 2079-01-10         Income  Resturant  Food  Sujan Tulachan
# 7 2079-01-10         Income  Resturant  Food  Sujan Tulachan
#
# 1        PARTICULAR  QTY     UOM  CREDIT    CASH  ...  NaN  NaN  NaN  NaN  \
# 0              Room  1.0     Day     NaN  2000.0  ...  NaN  NaN  NaN  NaN
# 1              Room  1.0     Day     NaN  2000.0  ...  NaN  NaN  NaN  NaN
# 2     Mineral Water  3.0  Bottle     NaN    90.0  ...  NaN  NaN  NaN  NaN
# 3  Normal Breakfast  2.0     Set     NaN   600.0  ...  NaN  NaN  NaN  NaN
# ...

# %%
#Loading and Cleaning Hotel Data from a CSV File, Setting appropriate headers


import pandas as pd

# Load the CSV file
file_name = 'Hotel Magh 2079.csv'  # Ensure the file extension is correct
hotel_data = pd.read_csv(file_name)

# Set the second row (index 1) as the header
hotel_data.columns = hotel_data.iloc[1]  # Use the second row as the header
hotel_data = hotel_data[2:].reset_index(drop=True)  # Drop the first two rows and reset the index

# Display the first few rows of the data
print(hotel_newdata.head())
# Out:
# 1        DATE INCOME/EXPENSE DEPARTMENT  TYPE VENDOR/COSTUMER  \
# 0  01/10/2079         Income       Room   202  Sujan Tulachan
# 1  01/10/2079         Income       Room   204  Sujan Tulachan
# 2  01/10/2079         Income  Resturant   Bar  Sujan Tulachan
# 3  01/10/2079         Income  Resturant  Food  Sujan Tulachan
# 4  01/10/2079         Income  Resturant  Food  Sujan Tulachan
#
# 1        PARTICULAR QTY     UOM CREDIT  CASH  ...  NaN  NaN  NaN  NaN  NaN  \
# 0              Room   1     Day    NaN  2000  ...  NaN  NaN  NaN  NaN  NaN
# 1              Room   1     Day    NaN  2000  ...  NaN  NaN  NaN  NaN  NaN
# 2     Mineral Water   3  Bottle    NaN    90  ...  NaN  NaN  NaN  NaN  NaN
# 3  Normal Breakfast   2     Set    NaN   600  ...  NaN  NaN  NaN  NaN  NaN
# 4          Veg Soup   1    Boul    NaN   150  ...  NaN  NaN  NaN  NaN  NaN
#
# 1  NaN  NaN  NaN  NaN  NaN
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN
# ...

# %%
hotel_data.shape
# Out:
# (1483, 31)

# %%
#Dataset Overview and Missing Values Analysis

# Step 1: Dataset Overview
print("Dataset Overview:")
print(f"Total Rows: {hotel_newdata.shape[0]}")
print(f"Total Columns: {hotel_newdata.shape[1]}")
print(f"Columns with Missing Values:\n{hotel_newdata.isnull().sum()}\n")
# Out:
# Dataset Overview:
# Total Rows: 1483
# Total Columns: 26
# Columns with Missing Values:
# 1
# DATE                200
# INCOME/EXPENSE      200
# DEPARTMENT          200
# TYPE                200
# VENDOR/COSTUMER     200
# PARTICULAR          200
# QTY                 319
# UOM                 319
# CREDIT              874
# CASH                809
# REMARKS             272
# TYPER               200
# CREDITOR/DEBTOR     200
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# dtype: int64

# %%
#"Dataset Summary and Data Types Information"

hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1483 entries, 0 to 1482
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DATE             1283 non-null   object
#  1   INCOME/EXPENSE   1283 non-null   object
#  2   DEPARTMENT       1283 non-null   object
#  3   TYPE             1283 non-null   object
#  4   VENDOR/COSTUMER  1283 non-null   object
#  5   PARTICULAR       1283 non-null   object
#  6   QTY              1164 non-null   object
#  7   UOM              1164 non-null   object
#  8   CREDIT           609 non-null    object
#  9   CASH             674 non-null    object
#  10  REMARKS          1211 non-null   object
#  11  TYPER            1283 non-null   object
#  12  CREDITOR/DEBTOR  1283 non-null   object
#  13  nan              0 non-null      float64
#  14  nan              0 non-null      float64
#  15  nan              0 non-null      float64
# ...

# %%
# Check for missing values
missing_data = hotel_data.isnull().sum()
print(f"Missing data per column:\n{missing_data[missing_data > 0]}")

# Fill missing numerical values with the mean of the column
hotel_data['CREDIT'] = hotel_data['CREDIT'].fillna(hotel_data['CREDIT'].mean())
hotel_data['CASH'] = hotel_data['CASH'].fillna(hotel_data['CASH'].mean())

# Fill missing categorical values with 'Unknown'
hotel_data['VENDOR/COSTUMER'] = hotel_data['VENDOR/COSTUMER'].fillna('Unknown')

# Check if all missing values are handled
print(f"Missing data after handling:\n{hotel_data.isnull().sum()}")
# Out:
# Missing data per column:
# 1
# DATE                979
# INCOME/EXPENSE      200
# DEPARTMENT          200
# TYPE                200
# PARTICULAR          200
# QTY                 323
# UOM                 319
# REMARKS             272
# TYPER               200
# CREDITOR/DEBTOR     200
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# NaN                1483
# Month               979
# Year                979
# DAY                 979
# dtype: int64
# Missing data after handling:
# 1
# DATE                979
# INCOME/EXPENSE      200
# DEPARTMENT          200
# TYPE                200
# VENDOR/COSTUMER       0
# PARTICULAR          200
# QTY                 323
# UOM                 319
# CREDIT                0
# ...

# %%
#Convert Necessary rows to numerical form

hotel_data['QTY'] = pd.to_numeric(hotel_data['QTY'], errors='coerce')
hotel_data['CREDIT'] = pd.to_numeric(hotel_data['CREDIT'], errors='coerce')
hotel_data['CASH'] = pd.to_numeric(hotel_data['CASH'], errors='coerce')
hotel_data['DATE'] = pd.to_datetime(hotel_data['DATE'], errors='coerce')

# %%
hotel_data.dtypes
# Out:
# 1
# DATE               datetime64[ns]
# INCOME/EXPENSE             object
# DEPARTMENT                 object
# TYPE                       object
# VENDOR/COSTUMER            object
# PARTICULAR                 object
# QTY                       float64
# UOM                        object
# CREDIT                    float64
# CASH                      float64
# REMARKS                    object
# TYPER                      object
# CREDITOR/DEBTOR            object
# NaN                       float64
# NaN                       float64
# NaN                       float64
# NaN                       float64
# NaN                       float64
# NaN                       float64
# NaN                       float64
# NaN                       float64
# NaN                       float64
# NaN                       float64
# NaN                       float64
# NaN                       float64
# NaN                       float64
# Month                     float64
# ...

# %%
# MEAN BY CASH

hotel_data["CASH"].mean()
# Out:
# 3649.028189910979

# %%
# MEAN BY CREDIT

hotel_data["CREDIT"].mean()
# Out:
# 1817.2412972085385

# %%
import pandas as pd

# Assuming hotel_data is already loaded

# Count occurrences in 'VENDOR/COSTUMER' category
vendor_count = hotel_data['VENDOR/COSTUMER'].value_counts()

# Count occurrences in 'DEPARTMENT' category
department_count = hotel_data['DEPARTMENT'].value_counts()

# Count occurrences in 'PARTICULAR' category
particular_count = hotel_data['PARTICULAR'].value_counts()

# Print counts
print("Vendor/Customer Count:")
print(vendor_count)

print("\nDepartment Count:")
print(department_count)

print("\nParticular Count:")
print(particular_count)
# Out:
# Vendor/Customer Count:
# VENDOR/COSTUMER
# Unknown                           200
# Guddu Veg Shop                    149
# Joshi Quality Kirana pasal        126
# Manakamana Icecream Stores         56
# Shrestha Kirana Pasal              49
#                                  ...
# Deepa Shrestha (Gorkha Palace)      1
# Raju Khanal                         1
# Rojan Shrestha                      1
# Sumitra Bhattarai                   1
# Nirmal Adhikari                     1
# Name: count, Length: 171, dtype: int64
#
# Department Count:
# DEPARTMENT
# Restaurant       501
# Kitchen          422
# Adminstration    228
# Room             132
# Name: count, dtype: int64
#
# Particular Count:
# PARTICULAR
# Room             130
# Chicken Khana     34
# Discount          33
# Milk Coffee       24
# Milk              24
#                 ...
# Aalu Bujya         1
# Rahar Dal          1
# Tea Leaves         1
# Breadcrumb         1
# Ginger Honey       1
# ...

# %%
#"Grouping and Summarizing Credit by Department"


department_summary = hotel_data.groupby('DEPARTMENT')['CREDIT'].sum()
print(department_summary)
# Out:
# DEPARTMENT
# Adminstration    383234.418309
# Kitchen          753422.579885
# Restaurant       957273.938998
# Room             237589.647126
# Name: CREDIT, dtype: float64

# %%
#"Visualizing Total Credit by Department"


import matplotlib.pyplot as plt
import seaborn as sns

# Plot income/expense by department
department_summary.plot(kind='bar', title='Income/Expense by Department')
plt.xlabel('Department')
plt.ylabel('Total Credit')
plt.show()

# %%
#Departments with payment above 1000

# Filter rows where CREDIT or CASH are greater than 1000
above_1000 = hotel_data[(hotel_data['CREDIT'] > 1000) | (hotel_data['CASH'] > 1000)]

# Display the filtered data
print(above_1000[['DATE', 'DEPARTMENT', 'CREDIT', 'CASH']])
# Out:
# 1          DATE  DEPARTMENT       CREDIT        CASH
# 0    2079-01-10        Room  1817.241297  2000.00000
# 1    2079-01-10        Room  1817.241297  2000.00000
# 2    2079-01-10  Restaurant  1817.241297    90.00000
# 3    2079-01-10  Restaurant  1817.241297   600.00000
# 4    2079-01-10  Restaurant  1817.241297   150.00000
# ...         ...         ...          ...         ...
# 1478        NaT         NaN  1817.241297  3649.02819
# 1479        NaT         NaN  1817.241297  3649.02819
# 1480        NaT         NaN  1817.241297  3649.02819
# 1481        NaT         NaN  1817.241297  3649.02819
# 1482        NaT         NaN  1817.241297  3649.02819
#
# [1483 rows x 4 columns]

# %%
#1. Check the unique values in the VENDOR/COSTUMER column:

print(hotel_data['VENDOR/COSTUMER'].unique())
# Out:
# ['Sujan Tulachan' 'Gaurav Maskey' 'Manakamana Icecream Stores'
#  'Local Market' 'Guddu Veg Shop' 'Kumar Shurketi' 'Shrestha Kirana Pasal'
#  'Outguest' 'Naresh Electronic Center' 'Office (Shreejan Mushyaju)'
#  'Bibash Shrestha' 'Bhabana Stores'
#  'Pushpanjali Pustak Tatha Puja Statineory Center' 'Dinesh B.K'
#  'Gorkha Mineral Water Udhyog' 'Reeta Shakya' 'Abhimanyu Kumar'
#  'Guddu Das' 'Out Guest' 'Gorkha Mini Mart' 'Sujit Shrestha'
#  'Deepa Shrestha (Gorkha Palace)' 'Ishwor Maskey Sir'
#  'Shree Muna Kirana Stores' 'Jeevan Jyoti Shrestha' 'Sonu Nepali'
#  'Joshi Quality Kirana pasal' 'Upendra Khatri' 'Binod Man Rajbandari'
#  'Bhim Uperkoti' 'Babul Kumar (Fasle Celling Mistry)' 'Dhurba Regmi'
#  'Lok Bhadur Gurung' 'Uttam B.K' 'Amalya Office (Prem Gurung)'
#  'Suraj Priyar' 'Sachin Sharma' 'Aryal Bejuli Pasal' 'Shiva Kumar Khadka'
#  'Sher Bdr Rana (Hotel Inside)' 'Kausal Kirana Pasal' 'Rabindra Shrestha'
# ...

# %%
# Remove rows where the vendor is 'Unknown' or missing (NaN)
hotel_data_cleaned = hotel_data[~hotel_data['VENDOR/COSTUMER'].isin(['Unknown', ''])]

# Group by vendor and sum the CREDIT and CASH
vendor_summary = hotel_data_cleaned.groupby('VENDOR/COSTUMER')[['CREDIT', 'CASH']].sum()

# Create a new column for the total of CASH and CREDIT
vendor_summary['TOTAL'] = vendor_summary['CREDIT'] + vendor_summary['CASH']
print(vendor_summary)

# Find the vendor with the highest total
highest_vendor = vendor_summary['TOTAL'].idxmax()
highest_vendor_data = vendor_summary.loc[highest_vendor]

print(f"Vendor with the highest total cash or credit: {highest_vendor}")
print(f"Total amount: {highest_vendor_data['TOTAL']}")
# Out:
# 1                                  CREDIT         CASH         TOTAL
# VENDOR/COSTUMER
# Aakriti Metal Udhyog         12720.689080  41150.00000  53870.689080
# Abhimanyu Kumar              14537.930378   3600.00000  18137.930378
# Abhishek Adhikari            21806.895567   6900.00000  28706.895567
# Ajaya Gurung                  7268.965189   2470.00000   9738.965189
# Amalya Office (Prem Gurung)   2100.000000   7298.05638   9398.056380
# ...                                   ...          ...           ...
# Umar Faruk Fresh House        1817.241297  12285.00000  14102.241297
# Umer Faruk Fresh House        3634.482594  17880.00000  21514.482594
# Upendra Khatri                3634.482594  17000.00000  20634.482594
# Uttam B.K                     9086.206486   1600.00000  10686.206486
# Vibek Regmi                   5451.723892   4200.00000   9651.723892
#
# [170 rows x 3 columns]
# Vendor with the highest total cash or credit: Joshi Quality Kirana pasal
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Convert 'CREDIT' and 'CASH' columns to numeric, coercing errors to NaN
hotel_data['CREDIT'] = pd.to_numeric(hotel_data['CREDIT'], errors='coerce')
hotel_data['CASH'] = pd.to_numeric(hotel_data['CASH'], errors='coerce')

# Remove rows where 'VENDOR/COSTUMER' is "Unknown" or missing (NaN)
hotel_data_cleaned = hotel_data[~hotel_data['VENDOR/COSTUMER'].isin(['Unknown', ''])]

# Group by vendor and sum the CREDIT and CASH
vendor_summary = hotel_data_cleaned.groupby('VENDOR/COSTUMER')[['CREDIT', 'CASH']].sum()

# Create a new column for the total of CASH and CREDIT
vendor_summary['TOTAL'] = vendor_summary['CREDIT'] + vendor_summary['CASH']

# Sort by TOTAL in descending order and get the top 10 vendors
top_10_vendors = vendor_summary.sort_values(by='TOTAL', ascending=False).head(10)

# Plot the top 10 vendors
plt.figure(figsize=(12, 6))  # Set figure size
ax = top_10_vendors['TOTAL'].plot(kind='bar', color='skyblue', edgecolor='black')  # Bar chart

# Add bar values on top of each bar
for i, v in enumerate(top_10_vendors['TOTAL']):
    ax.text(i, v + 50, f'{v:.2f}', ha='center', va='bottom', fontsize=10)  # Annotate bars

# Title and labels
plt.title('Top 10 Vendors with Highest Payments (CREDIT + CASH)', fontsize=14)
plt.xlabel('Vendor', fontsize=12)
plt.ylabel('Total Payment', fontsize=12)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent label cut-off

# Show the plot
plt.show()

# %%
#Total sales by Cash and Credit

# Calculate total sales for 'CREDIT' and 'CASH' separately
total_credit_sales = hotel_data['CREDIT'].sum()
total_cash_sales = hotel_data['CASH'].sum()

# Print the total sales by CASH and CREDIT
print(f"Total Sales by CREDIT: {total_credit_sales:.2f}")
print(f"Total Sales by CASH: {total_cash_sales:.2f}")
# Out:
# Total Sales by CREDIT: 2694968.84
# Total Sales by CASH: 5411508.81

# %%
#Replace Resturant by Restaurant

hotel_data['DEPARTMENT'] = hotel_data['DEPARTMENT'].replace('Resturant', 'Restaurant')
hotel_data
# Out:
# 1          DATE INCOME/EXPENSE  DEPARTMENT  TYPE VENDOR/COSTUMER  \
# 0    2079-01-10         Income        Room   202  Sujan Tulachan
# 1    2079-01-10         Income        Room   204  Sujan Tulachan
# 2    2079-01-10         Income  Restaurant   Bar  Sujan Tulachan
# 3    2079-01-10         Income  Restaurant  Food  Sujan Tulachan
# 4    2079-01-10         Income  Restaurant  Food  Sujan Tulachan
# ...         ...            ...         ...   ...             ...
# 1478        NaT            NaN         NaN   NaN         Unknown
# 1479        NaT            NaN         NaN   NaN         Unknown
# 1480        NaT            NaN         NaN   NaN         Unknown
# 1481        NaT            NaN         NaN   NaN         Unknown
# 1482        NaT            NaN         NaN   NaN         Unknown
#
# 1           PARTICULAR  QTY     UOM       CREDIT        CASH  ...  NaN  NaN  \
# 0                 Room  1.0     Day  1817.241297  2000.00000  ...  NaN  NaN
# ...

# %%
import matplotlib.pyplot as plt

# Convert 'CREDIT' and 'CASH' to numeric values
hotel_data['CREDIT'] = pd.to_numeric(hotel_data['CREDIT'], errors='coerce')
hotel_data['CASH'] = pd.to_numeric(hotel_data['CASH'], errors='coerce')

# Calculate total sales (CREDIT + CASH) for each department
hotel_data['TOTAL_SALES'] = hotel_data['CREDIT'] + hotel_data['CASH']

# Group by 'DEPARTMENT' and sum the total sales
department_sales = hotel_data.groupby('DEPARTMENT')['TOTAL_SALES'].sum().sort_values(ascending=False)

# Plot the total sales by department
plt.figure(figsize=(12, 6))  # Set figure size for better readability
ax = department_sales.plot(kind='bar', color='skyblue', title='Total Sales by Department', edgecolor='black')

# Add bar values on top of each bar
for i, v in enumerate(department_sales):
    ax.text(i, v + 50, f'{v:.2f}', ha='center', va='bottom', fontsize=10)  # Annotate bars with values

# Adding labels and title
plt.xlabel('Department')
plt.ylabel('Total Sales')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()  # Adjust layout to make room for labels

# Show the plot
plt.show()

# %%
#SALES BY DEPARTMENT

import matplotlib.pyplot as plt
import pandas as pd

# Group by 'PARTICULAR' (assuming this column represents the type of food) and sum the sales
food_sales = hotel_data.groupby('PARTICULAR')['TOTAL_SALES'].sum().sort_values(ascending=False)
print(food_sales)

# Display the type of food with the highest sales
print(f"Type of Food with the Most Sales: {food_sales.idxmax()} - Sales: {food_sales.max():.2f}")

# Plot the sales of the top 10 food items
plt.figure(figsize=(10, 6))  # Adjust the figure size for better readability
ax = food_sales.head(10).plot(kind='bar', color='lightgreen', title='Top 10 Food Sales')

# Add bar values on top of each bar
for i, v in enumerate(food_sales.head(10)):
    ax.text(i, v + 50, f'{v:.2f}', ha='center', va='bottom', fontsize=10)

# Title and labels
plt.xlabel('Food Type')
plt.ylabel('Total Sales')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()  # Adjust layout to make room for labels

# Show the plot
plt.show()
# Out:
# PARTICULAR
# Room                   504890.336096
# Past Credit Payment    462677.930378
# Khana Set              413057.538974
# Snacks+Khana Set       401767.241297
# Khana+Snacks           391817.241297
#                            ...
# Tipex                    1867.241297
# Tape                     1867.241297
# Hot Lemon                1867.241297
# Bora                     1867.241297
# Medician                 1837.241297
# Name: TOTAL_SALES, Length: 382, dtype: float64
# Type of Food with the Most Sales: Room - Sales: 504890.34

# %%
# FOOD SALES

import matplotlib.pyplot as plt
import pandas as pd

# Group by 'PARTICULAR' (assuming this column represents the type of food) and sum the sales
food_sales = hotel_data.groupby('PARTICULAR')['TOTAL_SALES'].sum().sort_values(ascending=False)
print(food_sales)

# Display the type of food with the highest sales
print(f"Type of Food with the Most Sales: {food_sales.idxmax()} - Sales: {food_sales.max():.2f}")

# Plot the sales of the top 10 food items
plt.figure(figsize=(10, 6))  # Adjust the figure size for better readability
ax = food_sales.head(10).plot(kind='bar', color='darkblue', title='Top 10 Food Sales')

# Add bar values on top of each bar
for i, v in enumerate(food_sales.head(10)):
    ax.text(i, v + 50, f'{v:.2f}', ha='center', va='bottom', fontsize=10)

# Title and labels
plt.xlabel('Food Type')
plt.ylabel('Total Sales')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.tight_layout()  # Adjust layout to make room for labels

# Show the plot
plt.show()
# Out:
# PARTICULAR
# Room                   504890.336096
# Past Credit Payment    462677.930378
# Khana Set              413057.538974
# Snacks+Khana Set       401767.241297
# Khana+Snacks           391817.241297
#                            ...
# Tipex                    1867.241297
# Tape                     1867.241297
# Hot Lemon                1867.241297
# Bora                     1867.241297
# Medician                 1837.241297
# Name: TOTAL_SALES, Length: 382, dtype: float64
# Type of Food with the Most Sales: Room - Sales: 504890.34

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Convert 'CREDIT' and 'CASH' columns to numeric, coercing errors to NaN
hotel_data['CREDIT'] = pd.to_numeric(hotel_data['CREDIT'], errors='coerce')
hotel_data['CASH'] = pd.to_numeric(hotel_data['CASH'], errors='coerce')

# Remove rows where 'VENDOR/COSTUMER' is "Unknown" or missing (NaN)
hotel_data_cleaned = hotel_data[~hotel_data['VENDOR/COSTUMER'].isin(['Unknown', ''])]

# Group by 'VENDOR/COSTUMER' and sum 'CREDIT' and 'CASH'
vendor_sales = hotel_data_cleaned.groupby('VENDOR/COSTUMER')[['CREDIT', 'CASH']].sum()

# Create a new column for total sales (CREDIT + CASH)
vendor_sales['TOTAL'] = vendor_sales['CREDIT'] + vendor_sales['CASH']

# Sort vendors by total sales in descending order
vendor_sales_sorted = vendor_sales['TOTAL'].sort_values(ascending=False)

# Plotting the top 10 vendors by total sales
plt.figure(figsize=(12, 6))  # Set the figure size for better readability
ax = vendor_sales_sorted.head(10).plot(kind='bar', title='Top 10 Vendors/Customers by Total Sales', color='skyblue', edgecolor='black')

# Add bar values on top of each bar
for i, v in enumerate(vendor_sales_sorted.head(10)):
    ax.text(i, v + 50, f'{v:.2f}', ha='center', va='bottom', fontsize=10)  # Annotate the bars with values

# Adding labels and title
plt.xlabel('Vendor/Customer')
plt.ylabel('Total Sales')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent label cut-off

# Show the plot
plt.show()

# %%
# Group by 'DATE' and sum 'CREDIT' and 'CASH' for each day
daily_cash_sales = hotel_data.groupby('DATE')['CASH'].sum()
daily_credit_sales = hotel_data.groupby('DATE')['CREDIT'].sum()

# Plotting
plt.plot(daily_cash_sales.index, daily_cash_sales, label='Cash Sales', color='b')
plt.plot(daily_credit_sales.index, daily_credit_sales, label='Credit Sales', color='orange')
plt.title('Cash vs Credit Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %%
# Ensure that 'QTY', 'CREDIT', and 'CASH' are numeric
hotel_data['QTY'] = pd.to_numeric(hotel_data['QTY'], errors='coerce')
hotel_data['CREDIT'] = pd.to_numeric(hotel_data['CREDIT'], errors='coerce')
hotel_data['CASH'] = pd.to_numeric(hotel_data['CASH'], errors='coerce')

# Calculate correlation
correlation = hotel_data[['QTY', 'CREDIT', 'CASH']].corr()

# Plotting the correlation heatmap
import seaborn as sns
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation between Quantity and Sales')
plt.show()

# %%
# Group by 'DEPARTMENT' and sum 'CASH' and 'CREDIT' sales
department_cash_credit = hotel_data.groupby('DEPARTMENT').agg({'CASH': 'sum', 'CREDIT': 'sum'})

# Plotting
department_cash_credit.plot(kind='bar', stacked=True, title='Cash vs Credit Payment Mode by Department')
plt.xlabel('Department')
plt.ylabel('Total Sales')
plt.show()

# %%
# Using IQR to detect outliers in sales

Q1 = hotel_data['CREDIT'].quantile(0.25)
Q3 = hotel_data['CREDIT'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers
outliers = hotel_data[(hotel_data['CREDIT'] < lower_bound) | (hotel_data['CREDIT'] > upper_bound)]

# Plotting
plt.boxplot(hotel_data['CREDIT'])
plt.title('Outlier Detection in Sales')
plt.ylabel('Sales')
plt.show()

# %%
# Plotting a scatter plot to show the relationship between SALES and CREDIT
plt.scatter(hotel_data['CREDIT'], hotel_data['TOTAL_SALES'], alpha=0.5)
plt.title('Sales vs. Credit')
plt.xlabel('Credit')
plt.ylabel('Total Sales')
plt.show()

# %%
import seaborn as sns
# Calculate correlation matrix
correlation_matrix = hotel_data[['CREDIT', 'CASH', 'TOTAL_SALES']].corr()

# Plotting the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Convert 'DATE' to datetime format (if not already)
hotel_data['DATE'] = pd.to_datetime(hotel_data['DATE'])

# Create a new column 'Weekday' from the date
hotel_data['Weekday'] = hotel_data['DATE'].dt.day_name()

# Group by weekday and sum the sales
weekday_sales = hotel_data.groupby('Weekday')['TOTAL_SALES'].sum().sort_values(ascending=False)

# Plot sales by weekday
weekday_sales.plot(kind='bar', color='lightseagreen', title='Sales by Weekday')
plt.xlabel('Weekday')
plt.ylabel('Total Sales')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your dataset is loaded into `hotel_data`

# Group by the 'TYPER' column and count the occurrences of each typer
typer_count = hotel_data['TYPER'].value_counts()

# Find the typer with the most occurrences
top_typer = typer_count.idxmax()
top_typer_count = typer_count.max()

# Print out the results
print(f"Typer with the most entries: {top_typer}")
print(f"Number of times typed: {top_typer_count}")

# Plotting the number of times each typer appears
plt.figure(figsize=(14, 8))  # Adjusted figsize for larger graph
ax = typer_count.plot(kind='bar', color='lightcoral', edgecolor='black')

# Adding labels and title
plt.title('Number of Times Each Typer Has Typed', fontsize=20)
plt.xlabel('Typer', fontsize=18)
plt.ylabel('Count', fontsize=18)
plt.xticks(rotation=0, ha='right')  # Rotate x-axis labels for better readability

# Add bar values on top of each bar
for i, v in enumerate(typer_count):
    ax.text(i, v + 0.1, str(v), ha='center', va='bottom', fontsize=10)  # Adjust 0.1 if values are too close to bars

# Tight layout to ensure everything fits well
plt.tight_layout()  # Adjust layout to prevent label cut-off

# Show the plot
plt.show()
# Out:
# Typer with the most entries: s
# Number of times typed: 784
