# %%
#Day_5 CS
#if
i=10

if (i<15):
  print(" 10 is less than 15")
# Out:
#  10 is less than 15

# %%
# if condition is not true
if (i<15):
  print(" 10 is less than 15")
print("Have a  nice day...!!")
# Out:
#  10 is less than 15
# Have a  nice day...!!

# %%
# if-else
if (i<15):
  print(" Hi")
else:
  print("Hello")
print("Have a  nice day...!!")
# Out:
#  Hi
# Have a  nice day...!!

# %%
#Check number is even or odd

number=int(input("Enter a number:"))
if number%2==0:
  print(f"{number} is even number")
else:
  print(f"{number} is odd number")
# Out:
# Enter a number:27
# 27 is odd number

# %%
# ==,>,<,>=,<=,!=
# if -elif -else
x=27
if x%2==0:
  print("X is Divisible by 2")
elif x%3==0:
  print("X is Divisible by 3")
else:
  print("X is neither divisible by 2 nor 3")
# Out:
# X is Divisible by 3

# %%
username=input("Enter Username")
passward=input("Enter passward")
#Syntax: if (condition): statement elif (condition): statement . . else: statement
if username=="admin" and passward=="pswrd123":
  print("Login Successful...!!!")
else:
  print("invalid user")
# Out:
# Enter UsernameOmics
# Enter passwardlabs
# invalid user

# %%
#LOOP-for ,while
list1=[10,20,30,40,50]

# %%
dna_seq=["AGCGTA","ACGATAGACGAT","ACGATAG","ACAGATAG"]
dna_seq
for sequence in dna_seq:
  seq_length=len(sequence)
  print(sequence)
  print(seq_length)
# Out:
# AGCGTA
# 6
# ACGATAGACGAT
# 12
# ACGATAG
# 7
# ACAGATAG
# 8

# %%
list_of_num=[2,4,6,9,5]
for i in list_of_num:
  if i%2!=0:
    print(i,":is an odd number")
  if i%2==0:
    print(i,":is an even number")
# Out:
# 2 :is an even number
# 4 :is an even number
# 6 :is an even number
# 9 :is an odd number
# 5 :is an odd number

# %%
# while-
i=1
while i<6:
  print(i)
  i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# break,continue

for i in range(10):
  if i==5:
    print("Breaking the loop at i=",i)
    break
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# Breaking the loop at i= 5

# %%
# Continue
for i in range(10):
  if i==3:
    print("Breaking the loop at i=",i)
    continue
  print(i)
# Out:
# 0
# 1
# 2
# Breaking the loop at i= 3
# 4
# 5
# 6
# 7
# 8
# 9
