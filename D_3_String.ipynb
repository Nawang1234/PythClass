# %% [markdown]
# # DAY-3 String handling
# # Indexing-positive,negative
# # Slicing[start:end:skip]

# %% [markdown]
# Eg. Sequence = “ABCD”
# 		A	B	C	D
# 		0	1	2	3
#    -4-3-2-1

# %% [markdown]
# #single ,double,triple
# '',"",'''string'''

# %%
dna_seq="ACGTACAGATCAGATACAGATAG"
len(dna_seq)
#fetch single elemt [index_id]
# Slicing[start_id:end_index_id]
# Out:
# 23

# %%
string="hello"
string[0]
string[-1]
string[1:4]
string.capitalize()
string.
# Out:
# 'Hello'

# %%
string="hello"
string[-4:]
# Out:
# 'ello'

# %%
string.endswith,string.count(),string.replace("AT","CG")

# %%
dna_seq="ACGTACAGATCAGATACAGATAG"
print("Original dna sequence:",dna_seq)
rev_seq=dna_seq[::-1]
print("reverse dna sequence:",rev_seq)
slice_1=dna_seq[:10]
slice_1
slice_2=dna_seq[2:20:3]
slice_2
# Out:
# Original dna sequence: ACGTACAGATCAGATACAGATAG
# reverse dna sequence: GATAGACATAGACTAGACATGCA
# 'GCAATA'

# %%
data="MSYVVAIPDMLASAAADVAGIGSSVG"
lenght=len(data)
lenght
half=lenght/2
half

half=int(lenght/2)
half
# Out:
# 13

# %%
first_half=data[:half]
len(first_half)
second_half=data[half:]
len(second_half)
print(first_half,second_half)
# Out:
# MSYVVAIPDMLAS AAADVAGIGSSVG

# %%
print("Original dna sequence:",dna_seq)
count_A=dna_seq.count("A")
print("Count of A :",count_A)

count_C=dna_seq.count("C")
print("Count of C :",count_C)
# Out:
# Original dna sequence: ACGTACAGATCAGATACAGATAG
# Count of A : 10
# Count of C : 4

# %%
substring_index=dna_seq.find("GAT")
substring_index
# Out:
# 7

# %%
#lower ,upper
lower_seq=dna_seq.lower()
print("Original dna sequence:",dna_seq)
print("Lowercase of seq:",lower_seq)
upper_seq=lower_seq.upper()
upper_seq
# Out:
# Original dna sequence: ACGTACAGATCAGATACAGATAG
# Lowercase of seq: acgtacagatcagatacagatag
# 'ACGTACAGATCAGATACAGATAG'

# %%
replace_seq=dna_seq.replace("AC","xx")
replace_seq
# Out:
# 'xxGTxxAGATCAGATxxAGATAG'

# %%
# fetch first 5 and last five
#dna_seq[0:6]
dna_seq[:5]
# last five
last_five=dna_seq[-5:]
print(f"Last five bases:{last_five}")
# Out:
# Last five bases:GATAG

# %%
#d[::5]
str="Hello World!"
str
# get second char
every_second_char="Hello,world!"[::2]
every_second_char
# Out:
# 'Hlowrd'

# %%
#list,datframe,set,tuple,dict
