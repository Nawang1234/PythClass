# %%
#day_4-DS
# built-in-List,tuple,set and dict

# %%
list1=[1,2,3,4,5,6,7]
type(list1)
list2=["DNA","RNA","AA"]
list2
#indexing
list1[-1]
#SLicing
list1[2:5]
list3=[["DNA","RNA","AA"],["enzyme"]]
len(list3)
list3[1]
list3[0][2]
# Out:
# 'AA'

# %%
fruits=['apple','banana']
fruits.append("fig")
fruits
# Out:
# ['apple', 'banana', 'fig']

# %%
x=[1,2,3]
y=x
y+=[4,5]
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
old_list=[1,2,3,4,5]
new_list=old_list
old_list[0]=7
print(new_list)
# Out:
# [7, 2, 3, 4, 5]

# %%
print(bool(0),bool(3.14),bool(-1))
# Out:
# False True True

# %%
#Tuple
#1
x=()
x
type(x)
#2
tuple1=tuple()
tuple1
type(tuple1)
#3
t3=100,200,300,400,500
type(t3)
#4

t4=[100,200,300,400,500]
type(t4)
t5=tuple(t4)
t5
# Out:
# (100, 200, 300, 400, 500)

# %%
# set-unordered-no indexing,unique,mutable,{}
empty_set=set()
type(empty_set)

# set with multiple DT
set1={1,2,3,4,5,3.14,"NGS","CADD",22.7,99}
print("Set1:",set1)
type(set1)

set2={1,1,2,2,3,3,1,2,3,4,1,2,4,5,6,7,8,9,9}
set2
# Out:
# Set1: {1, 2, 3, 4, 5, 3.14, 99, 'NGS', 22.7, 'CADD'}
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
print("Elements from set1:")
for element in set1:
  print(element)
# Out:
# Elements from set1:
# 1
# 2
# 3
# 4
# 5
# 3.14
# 99
# NGS
# 22.7
# CADD

# %%
for i in set1:
  print(i,end="")
  print()

print("CADD2" in set1)
# Out:
# 1
# 2
# 3
# 4
# 5
# 3.14
# 99
# NGS
# 22.7
# CADD
# False

# %%
number={2,3,4,5,6,7}
number.add(100)
number
# Out:
# {2, 3, 4, 5, 6, 7, 100}

# %%
#number.remove(4)
number.discard(10)

# %%
print("Is 6 in the set?",6 in number)
# Out:
# Is 6 in the set? True

# %%
number.clear()
copied_number=number.copy()

# %%
# Dict---->key-value,mutable,key-unique
dict_0={}
type(dict_0)
dict1={1:'python',2:'R',3:'SQL'}
dict1
# get method
dict1.get(3)

dict2={'Name':'Omics',2:[1,2,3,4,5,6,7]}
dict2["Name"]='NGS'
dict2
# Out:
# {'Name': 'NGS', 2: [1, 2, 3, 4, 5, 6, 7]}
